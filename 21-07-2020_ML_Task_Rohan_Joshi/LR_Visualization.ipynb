# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Startups.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
plt.scatter(df["R&D Spend"],df["Profit"])

# %%
plt.scatter(df["Marketing Spend"],df["Profit"])

# %%
x = df["R&D Spend"]
y = df["Profit"]

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'o',color='r',label='trdata')
ax.plot(x,0.2+0.8*x, label='10000 + 900*x')

# %%
x = df["Marketing Spend"]
y = df["Profit"]

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'o',color='r',label='trdata')
ax.plot(x,0.1+0.5*x, label='10000 + 900*x')

# %%
x = df["Administration"]
y = df["Profit"]

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'o',color='r',label='trdata')
ax.plot(x,0.90+0.90*x, label='10000 + 900*x')

# %%
x = df["Administration"]
y = df["Marketing Spend"]

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'o',color='r',label='trdata')
ax.plot(x,1+2*x, label='10000 + 900*x')
